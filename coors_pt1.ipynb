# %% [markdown]
# # The Complete Effects of Coors Field: Part 1

# %% [markdown]
# Here we aim to thoroughly analyze the impact Coors Field has on MLB player performance. Given that this project is for practice and demonstrative purposes, we'll be handicapping ourselves in several ways. First, we'll be sticking to Python, only using data from Python libraries except when web scraping is absolutely necessary. There are packages in R that are great for doing baseball analysis, but we won't be using those. We also will be limiting our analysis to work we feel is reasonable for ad-hoc analysis, in part because we understand that real projects often have constraints to time and resources. Gathering actionable insights within those constraints is good practice. Given these handicaps, we'll try to point out where they prevented us from further analysis, and we'll outline what we felt would've been the next steps if we did go down those rabbit holes.
#
# Part 1 delves into the direct effects on performance at Coors Field. In our next part we'll go into the additional effects away from Coors Field, known as the "Coors Hangover Effect".
#
# If you'd only like to see the key takeaways or how we would build a story out of these results, you can read [our more concise report](https://github.com/skparagas/skparagas/blob/main/projects/The_Complete_Effects_of_Coors_Field__Part_1.pdf).

# %% [markdown]
# ## Glossary
#
# - AOP: all other parks. MLB parks except Coors Field
# - BABIP: batting average on balls in play. Essentially excludes strikeouts and home runs
# - BAHB: batting average on hit balls. BABIP but with home runs included
# - BBE: batted ball event. Any ball in play including home runs
# - EV: exit velocity. The speed (in MPH) of a BBE coming off the bat
# - ISO: isolated power. Slugging percentage minus batting average, representing a player's extra-base production
# - LA: launch angle. The angle (in deg) of a BBE coming off the bat
# - wOBA: weighted On-Base Average. An all encompassing metric that represents offensive production
# - wOBAcon: weighted On-Base Average on Contact. wOBA only for BBEs, excluding strikeouts, walks, and hit by pitches
# - wRC+: weighted Runs Created Plus. wOBA but taken a couple steps further, accounting for park factors and standardized
# - XBH: extra-base hits. Doubles, triples, and home runs
# - xwOBA: expected wOBA. Based off the BBE's launch angle and exit velocity
# - xwOBAcon: expected wOBA on Contact. Same as wOBAcon but for xwOBA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
import re
import json
from matplotlib import colors
from matplotlib.ticker import PercentFormatter, FormatStrFormatter, StrMethodFormatter
from matplotlib.patches import Rectangle
import seaborn as sns
from scipy.signal import savgol_filter
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.display.width = 0
pd.options.display.max_colwidth = 200
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Coors Effect

# %% [markdown]
# ### Park Altitude

# %%
PARK_URL = 'https://baseballsavant.mlb.com/leaderboard/statcast-park-factors'

params = {'type': 'distance', 'year': 2016}
response = requests.get(PARK_URL, params=params)
soup = BeautifulSoup(response.content, 'html.parser')

script_tags = soup.find_all('script')
for script in script_tags:
    match = re.search('var data = (.*);', script.text)
    if match:
        break

elevation = pd.DataFrame(json.loads(match[1]))
elevation['elevation_feet'] = elevation['elevation_feet'].astype(int)
elevation = elevation.sort_values(by='elevation_feet', ascending=False).reset_index()

# %%
pos = elevation[elevation.venue_name == 'Coors Field'].index[0]

fig, ax = plt.subplots()
ax.bar(elevation['venue_name'], elevation['elevation_feet'], color = 'gray')
ax.set_title('Elevation by MLB Stadium')
ax.set_xlabel('MLB Stadium')
ax.set_ylabel('Elevation (ft)')
ax.tick_params(axis='x', bottom=False, labelbottom=False)
ax.patches[pos].set_color('#33006F')
ax.legend(labels=[elevation['venue_name'][pos]])
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

plt.savefig("elevation.png", dpi=300)
plt.show()

# %% [markdown]
# This was collected from 2016. There were some additional stadiums significantly used since then. The Atlanta Braves moved from Turner Field to Truist Park in 2017 and the Texas Rangers moved from Globe Life Park to Globe Life Field in 2020. Neither moves resulted in a change in elevation according to Statcast. Additionally, the Toronto Blue Jays used Salhen Field (elevation 521 ft.) in Buffalo, NY for the 2020 and 2021 seasons before going back to Rogers Centre. The Athletics used Sutter Health Park (24 ft.) in Sacramento, CA for the 2025 season, and the Tampa Bay Rays used George M. Steinbrenner Field (34 ft.) in Tampa, FL for the 2025 season.

# %%
# This data was collected from the python library pybaseball in statcast.py, then made static to maintain consistency and reduce runtime
df = pd.read_csv('statcast_red.csv')

# %%
# Creating additional columns for analysis
df['park'] = df.apply(lambda row: 'Coors' if row['home_team'] == 'COL' else 'AOP', axis=1) 

df['bahb_value'] = df['babip_value']
df.loc[df['events'] == 'home_run', 'bahb_value'] = 1

df['plate_x_bucket'] = np.floor(df['plate_x'] / (5/18)) * (5/18) * 12
df['plate_z_bucket'] = np.floor((df['plate_z'] + 0.5) / (1/3)) * (1/3) * 12 - 6
df['zone_full'] = df.apply(lambda row: "inner heart" if (row['plate_x_bucket'] * 0.3 <= 0) & (row['plate_x_bucket'] * 0.3 >= -1) & (row['plate_z_bucket'] <= 30) & (row['plate_z_bucket'] >= 26)
                  else "heart" if (row['plate_x_bucket'] * 0.3 <= 1) & (row['plate_x_bucket'] * 0.3 >= -2) & (row['plate_z_bucket'] <= 34) & (row['plate_z_bucket'] >= 22)
                  else "shadow" if (row['plate_x_bucket'] * 0.3 <= 3) & (row['plate_x_bucket'] * 0.3 >= -4) & (row['plate_z_bucket'] <= 42) & (row['plate_z_bucket'] >= 14)
                  else "chase" if (row['plate_x_bucket'] * 0.3 <= 5) & (row['plate_x_bucket'] * 0.3 >= -6) & (row['plate_z_bucket'] <= 50) & (row['plate_z_bucket'] >= 6)
                  else "error" if (np.isnan(row['plate_x_bucket'])) | (np.isnan(row['plate_z_bucket']))
                  else "waste", axis=1)

# %% [markdown]
# ### The Pitch

# %% [markdown]
# #### Pitch Movement

# %%
min_pitches = 100

col_pitchers = df[~(df.pfx_z.isna()) & (df.park == 'Coors')].groupby(['player_name', 'pitch_name', 'game_year']).agg(
    pitch_count=('pitch_name', 'count'),
    horizontal_tot=('api_break_x_arm', 'mean'),
    vertical_tot=('api_break_z_with_gravity', 'mean'),
    vertical_ind=('pfx_z','mean')
).reset_index()

col_pitchers = col_pitchers[col_pitchers.pitch_count >= min_pitches]

aop_pitchers = df[~(df.pfx_z.isna()) & (df.park == 'AOP')].groupby(['player_name', 'pitch_name', 'game_year']).agg(
    pitch_count=('pitch_name', 'count'),
    horizontal_tot=('api_break_x_arm', 'mean'),
    vertical_tot=('api_break_z_with_gravity', 'mean'),
    vertical_ind=('pfx_z','mean')
).reset_index()

aop_pitchers = aop_pitchers[aop_pitchers.pitch_count >= min_pitches]

pitcher_movement = pd.merge(aop_pitchers, col_pitchers, on=['player_name', 'pitch_name', 'game_year'], how='inner')
pitcher_movement['horizontal_tot_diff'] = pitcher_movement.horizontal_tot_y - pitcher_movement.horizontal_tot_x
pitcher_movement['vertical_tot_diff'] = pitcher_movement.vertical_tot_y - pitcher_movement.vertical_tot_x
pitcher_movement['vertical_ind_diff'] = pitcher_movement.vertical_ind_y - pitcher_movement.vertical_ind_x
movement_summary = pitcher_movement.groupby(['pitch_name']).agg(
    pitcher_count=('player_name', 'count'),
    pitch_count_aop=('pitch_count_x', 'sum'),
    pitch_count_col=('pitch_count_y', 'sum'),
    horizontal_tot_aop=('horizontal_tot_x', 'mean'),
    horizontal_tot_col=('horizontal_tot_y', 'mean'),
    horizontal_tot_diff=('horizontal_tot_diff', 'mean'),
    vertical_tot_aop=('vertical_tot_x', 'mean'),
    vertical_tot_col=('vertical_tot_y', 'mean'),
    vertical_tot_diff=('vertical_tot_diff', 'mean'),
    vertical_ind_aop=('vertical_ind_x', 'mean'),
    vertical_ind_col=('vertical_ind_y', 'mean'),
    vertical_ind_diff=('vertical_ind_diff', 'mean'),
).reset_index()

movement_summary.iloc[:, 4:] = movement_summary.iloc[:, 4:].round(2)

movement_summary['horizontal_tot_perc'] = (movement_summary.horizontal_tot_diff / movement_summary.horizontal_tot_aop).apply(lambda x: f"{x:.0%}")
movement_summary['vertical_tot_perc'] = (movement_summary.vertical_tot_diff / movement_summary.vertical_tot_aop).apply(lambda x: f"{x:.0%}")
movement_summary['vertical_ind_perc'] = (movement_summary.vertical_ind_diff / movement_summary.vertical_ind_aop).apply(lambda x: f"{x:.0%}")

# %%
min_pitchers = 0
movement_summary[movement_summary.pitcher_count >= min_pitchers][['pitch_name', 'pitcher_count', 
                                                       'horizontal_tot_aop', 'horizontal_tot_perc', 
                                                       'vertical_ind_aop', 'vertical_ind_perc']].sort_values(by='pitcher_count', ascending=False)
# Out:
#         pitch_name  pitcher_count  horizontal_tot_aop horizontal_tot_perc  \
# 0  4-Seam Fastball            157                0.63                -22%
# 6           Slider             66               -0.32                 -6%
# 5           Sinker             60                1.23                -22%
# 1         Changeup             37                1.05                -22%
# 3           Cutter             34               -0.18                -17%
# 2        Curveball             24               -0.88                -17%
# 4    Knuckle Curve             18               -0.46                -30%
# 8          Sweeper              9               -1.22                -13%
# 7     Split-Finger              3                1.04                -26%
#
#    vertical_ind_aop vertical_ind_perc
# 0              1.31              -18%
# 6              0.23              -22%
# 5              0.65              -14%
# 1              0.60              -20%
# ...

# %% [markdown]
# We'll start our analysis with how Coors Field affects ball movement out of the pitcher's hand. Since pitches move differently depending on the pitcher and pitch type, we grouped pitches by these variables, as well as year to account for changes over time, and split them by when they were thrown at Coors Field vs. all other parks (AOP). Looking at pitchers with at least 100 pitches at both Coors and AOP, we calculated the straight average movement at AOP and how much less the average movement at Coors is.
#
# We have the average horizontally and vertically induced movement in inches for each pitch type in a standard MLB park (AOP), as well the percent difference in that movement at Coors. From this, we can see that pitches move less both horizontally and vertically at Coors across the board. Pitches move due to air resistance (drag) and the Magnus effect, which uses air density to create the force of lift and break. Because of the altitude, air density in Denver is roughly 18% lower than the air density at sea level, though other factors like temperature and humidity have an effect as well. Pitch movement should be directly proportional to air density, and our findings support that.

# %% [markdown]
# #### Pitch Location

# %% [markdown]
# The reduced pitch movement at Coors likely has an impact on pitch location, but this impact is difficult to observe due to excessive noise. Focusing on a single pitcher, there's natural variation in where he aims his pitches, dependent on factors like count and batter profile, as well as his execution of the intended location. Then there's variation across pitchers, since they utilize their arsenal in different ways. And pitchers are likely aware of the reduced pitch movement and may attempt to account for it, further hiding the signal within the noise.
#
# Beyond all the random noise, any changes in pitch location between Coors and AOP can't be solely attributed to the reduced movement, as pitchers likely change their approach at Coors given the extreme environment.
#
# Given all this, we decided to take a broader look at pitch location and limit our conclusions, though if we did go more in depth, we'd start by looking at the pitcher/pitch type level.

# %%
locations = df[['park', 'pitch_name', 'plate_x', 'plate_z', 'plate_x_bucket', 'plate_z_bucket', 'zone_full', 'api_break_x_arm', 'pfx_z', 'p_throws']]
locations_ff = locations[locations.pitch_name == '4-Seam Fastball'][['park', 'plate_x', 'plate_z']]

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4.8))
sns.kdeplot(data=locations_ff[locations_ff.park == 'AOP'], x='plate_x', y='plate_z', fill=True, cmap='coolwarm', thresh=0.8, levels=100, ax=ax1)
rect1 = Rectangle((-5/12, 1.5), 5/6, 2, fc='none', ec='black', lw=2)
ax1.add_patch(rect1)
ax1.set_xlim(-1, 1)
ax1.set_ylim(0.5, 4.5)
ax1.set_title('4-Seam Fastball\nAOP')
ax1.set_xlabel(None)
ax1.set_xticks([])
ax1.set_xticklabels([])
ax1.set_ylabel(None)
ax1.set_yticks([])
ax1.set_yticklabels([])

sns.kdeplot(data=locations_ff[locations_ff.park == 'Coors'], x='plate_x', y='plate_z', fill=True, cmap='coolwarm', thresh=0.8, levels=100, ax=ax2)
rect2 = Rectangle((-5/12, 1.5), 5/6, 2, fc='none', ec='black', lw=2)
ax2.add_patch(rect2)
ax2.set_xlim(-1, 1)
ax2.set_ylim(0.5, 4.5)
ax2.set_title('4-Seam Fastball\nCoors')
ax2.set_xlabel(None)
ax2.set_xticks([])
ax2.set_xticklabels([])
ax2.set_ylabel(None)
ax2.set_yticks([])
ax2.set_yticklabels([])
plt.show()

# %% [markdown]
# 4-seam fastballs are the most common pitch in baseball, with the most vertically induced movement. What we seem to be seeing here is that MLB pitchers tend to locate their fastballs in the upper half of the strikezone, but at Coors a fastball drops more than it typically does, resulting in balls locating a little lower.

# %%
locations_sl = locations[locations.pitch_name == 'Slider'][['park', 'plate_x', 'plate_z']]

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4.8))
sns.kdeplot(data=locations_sl[locations_sl.park == 'AOP'], x='plate_x', y='plate_z', fill=True, cmap='coolwarm', thresh=0.8, levels=100, ax=ax1)
rect1 = Rectangle((-5/12, 1.5), 5/6, 2, fc='none', ec='black', lw=2)
ax1.add_patch(rect1)
ax1.set_xlim(-1, 1)
ax1.set_ylim(0.5, 4.5)
ax1.set_title('Slider\nAOP')
ax1.set_xlabel(None)
ax1.set_xticks([])
ax1.set_xticklabels([])
ax1.set_ylabel(None)
ax1.set_yticks([])
ax1.set_yticklabels([])

sns.kdeplot(data=locations_sl[locations_sl.park == 'Coors'], x='plate_x', y='plate_z', fill=True, cmap='coolwarm', thresh=0.8, levels=100, ax=ax2)
rect2 = Rectangle((-5/12, 1.5), 5/6, 2, fc='none', ec='black', lw=2)
ax2.add_patch(rect2)
ax2.set_xlim(-1, 1)
ax2.set_ylim(0.5, 4.5)
ax2.set_title('Slider\nCoors')
ax2.set_xlabel(None)
ax2.set_xticks([])
ax2.set_xticklabels([])
ax2.set_ylabel(None)
ax2.set_yticks([])
ax2.set_yticklabels([])
plt.show()

# %%
locations_si = locations[locations.pitch_name == 'Sinker'][['park', 'plate_x', 'plate_z']]

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4.8))
sns.kdeplot(data=locations_si[locations_si.park == 'AOP'], x='plate_x', y='plate_z', fill=True, cmap='coolwarm', thresh=0.8, levels=100, ax=ax1)
rect1 = Rectangle((-5/12, 1.5), 5/6, 2, fc='none', ec='black', lw=2)
ax1.add_patch(rect1)
ax1.set_xlim(-1, 1)
ax1.set_ylim(0.5, 4.5)
ax1.set_title('Sinker\nAOP')
ax1.set_xlabel(None)
ax1.set_xticks([])
ax1.set_xticklabels([])
ax1.set_ylabel(None)
ax1.set_yticks([])
ax1.set_yticklabels([])

sns.kdeplot(data=locations_si[locations_si.park == 'Coors'], x='plate_x', y='plate_z', fill=True, cmap='coolwarm', thresh=0.8, levels=100, ax=ax2)
rect2 = Rectangle((-5/12, 1.5), 5/6, 2, fc='none', ec='black', lw=2)
ax2.add_patch(rect2)
ax2.set_xlim(-1, 1)
ax2.set_ylim(0.5, 4.5)
ax2.set_title('Sinker\nCoors')
ax2.set_xlabel(None)
ax2.set_xticks([])
ax2.set_xticklabels([])
ax2.set_ylabel(None)
ax2.set_yticks([])
ax2.set_yticklabels([])
plt.show()

# %%
locations_cu = locations[locations.pitch_name == 'Curveball'][['park', 'plate_x', 'plate_z']]

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4.8))
sns.kdeplot(data=locations_cu[locations_cu.park == 'AOP'], x='plate_x', y='plate_z', fill=True, cmap='coolwarm', thresh=0.8, levels=100, ax=ax1)
rect1 = Rectangle((-5/12, 1.5), 5/6, 2, fc='none', ec='black', lw=2)
ax1.add_patch(rect1)
ax1.set_xlim(-1, 1)
ax1.set_ylim(0.5, 4.5)
ax1.set_title('Curveball\nAOP')
ax1.set_xlabel(None)
ax1.set_xticks([])
ax1.set_xticklabels([])
ax1.set_ylabel(None)
ax1.set_yticks([])
ax1.set_yticklabels([])

sns.kdeplot(data=locations_cu[locations_cu.park == 'Coors'], x='plate_x', y='plate_z', fill=True, cmap='coolwarm', thresh=0.8, levels=100, ax=ax2)
rect2 = Rectangle((-5/12, 1.5), 5/6, 2, fc='none', ec='black', lw=2)
ax2.add_patch(rect2)
ax2.set_xlim(-1, 1)
ax2.set_ylim(0.5, 4.5)
ax2.set_title('Curveball\nCoors')
ax2.set_xlabel(None)
ax2.set_xticks([])
ax2.set_xticklabels([])
ax2.set_ylabel(None)
ax2.set_yticks([])
ax2.set_yticklabels([])
plt.show()

# %% [markdown]
# We looked at three additional types of pitches: slider, sinker, and curveball. All three had similar contour plots between pitch location at AOP and Coors. Note we didn't do anything to account for the different sample of pitchers at Coors vs. AOP, since Rockies pitchers would be more heavily weighted at Coors. We also don't account for the handedness of the pitchers, as a slider from a right-hander will move in the opposite direction as a slider from a left-hander.

# %% [markdown]
# ##### Right-Handed Pitchers

# %%
location_by_type_r = locations[locations.p_throws == 'R'].groupby(['pitch_name', 'park']).agg(
    pitch_count=('pitch_name', 'count'),
    horizontal_mov=('api_break_x_arm', 'mean'),
    vertical_mov=('pfx_z','mean'),
    horizontal_loc=('plate_x', 'mean'),
    vertical_loc=('plate_z', 'mean')
).reset_index().pivot(index='pitch_name', columns='park', values=['pitch_count', 'horizontal_mov', 'vertical_mov', 'horizontal_loc', 'vertical_loc'])

location_by_type_r['horizontal_loc_perc'] = ((location_by_type_r.horizontal_loc.Coors - location_by_type_r.horizontal_loc.AOP) / location_by_type_r.horizontal_loc.AOP).apply(lambda x: f"{x:.0%}")

location_by_type_r['pitch_count'] = location_by_type_r['pitch_count'].astype('Int64')
location_by_type_r.iloc[:, 2:] = location_by_type_r.iloc[:, 2:].round(2)

min_pitches = 1000
location_by_type_r[(location_by_type_r['pitch_count']['AOP'] >= min_pitches) & (location_by_type_r['pitch_count']['Coors'] >= min_pitches)].sort_values(by=('pitch_count','AOP'), ascending=False)
# Out:
#                 pitch_count        horizontal_mov       vertical_mov        \
# park                    AOP  Coors            AOP Coors          AOP Coors
# pitch_name
# 4-Seam Fastball     1785761  70675           0.62  0.45         1.34  1.04
# Sinker               889813  22198           1.22  0.92         0.74  0.55
# Slider               843598  32786          -0.43 -0.34         0.17  0.17
# Changeup             498959  15342           1.13  0.79         0.53  0.45
# Curveball            382620  12090          -0.82 -0.69        -0.78 -0.57
# Cutter               350859  12103          -0.23 -0.24         0.71  0.53
# Sweeper              148646   4809          -1.19 -1.04         0.10  0.00
# Split-Finger         131114   2669           0.90  0.66         0.33  0.32
# Knuckle Curve        129451   4232          -0.71 -0.46        -0.90 -0.54
#
#                 horizontal_loc       vertical_loc       horizontal_loc_perc
# ...

# %% [markdown]
# Here we account for handedness, looking at only right-handers first. Keep in mind, our horizontal movement metric was already based off throwing side (handedness) so we could look at pitch movement for both righties and lefties together. Positive values represent movement to the arm side (so right for righties) while negative values represent movement to the glove side (so left for righties). Our horizontal location metric doesn't account for handedness; positive values mean right of the plate from the catcher's perspective (so left of the plate from the pitcher's perspective), and vice versa for negative horizontal location values. For the sake of consistency, we'll discuss using left and right from the pitcher's perspective.
#
# Like with our contour plots, 4-seam fastballs our located a little lower on average at Coors than AOP, perhaps since the upward induced movement is reduced, though other pitch types with upward induced movement aren't necessarily seeing the same trend. Likewise, pitch types with downward induced movement aren't really seeing the opposite trend like you may expect. Although 4-seam fastballs have more than double the sample size of any of the other pitch types, there's just too much inconsistency and noise to really be conclusive about vertical location.
#
# For horizontal location, pitches that move to the right (and thus move to the right less at Coors) end up located more to the left at Coors. Conversely, pitches that move to the left (and thus move to the left less at Coors) end up located more to the right at Coors. And since pitchers tend to locate rightward induced pitches on the right side of the plate and leftward induced pitches on the left side, at Coors all these pitches end up more down the middle of the plate than they typically do.
#
# We calculated an estimate of this phenomenon, named `horizontal_loc_perc`, which represents the percent difference in the horizontal distance from the center of the plate at Coors vs. AOP. Although it's a bit crude and doesn't make sense for pitches that don't seem to have a common side of the plate (notably 4-seam fastballs), we can see less distance from the center of plate at Coors across all pitch types, hovering around the 18% decline we see with air density and pitch movement at Coors.

# %% [markdown]
# ##### Left-Handed Pitchers

# %%
location_by_type_l = locations[locations.p_throws == 'L'].groupby(['pitch_name', 'park']).agg(
    pitch_count=('pitch_name', 'count'),
    horizontal_mov=('api_break_x_arm', 'mean'),
    vertical_mov=('pfx_z','mean'),
    horizontal_loc=('plate_x', 'mean'),
    vertical_loc=('plate_z', 'mean')
).reset_index().pivot(index='pitch_name', columns='park', values=['pitch_count', 'horizontal_mov', 'vertical_mov', 'horizontal_loc', 'vertical_loc'])

location_by_type_l['horizontal_loc_perc'] = ((location_by_type_l.horizontal_loc.Coors - location_by_type_l.horizontal_loc.AOP) / location_by_type_l.horizontal_loc.AOP).apply(lambda x: f"{x:.0%}")

location_by_type_l['pitch_count'] = location_by_type_l['pitch_count'].astype('Int64')
location_by_type_l.iloc[:, 2:] = location_by_type_l.iloc[:, 2:].round(2)

min_pitches = 1000
location_by_type_l[(location_by_type_l['pitch_count']['AOP'] >= min_pitches) & (location_by_type_l['pitch_count']['Coors'] >= min_pitches)].sort_values(by=('pitch_count','AOP'), ascending=False)
# Out:
#                 pitch_count        horizontal_mov       vertical_mov        \
# park                    AOP  Coors            AOP Coors          AOP Coors
# pitch_name
# 4-Seam Fastball      654195  25082           0.68  0.58         1.34  1.12
# Sinker               368424  11221           1.24  1.02         0.80  0.68
# Slider               277024   8163          -0.41 -0.22         0.14  0.19
# Changeup             260436   9058           1.19  0.90         0.62  0.54
# Curveball            155338   3747          -0.72 -0.40        -0.75 -0.53
# Cutter               127038   7477          -0.12 -0.05         0.66  0.51
# Sweeper               47404   1248          -1.19 -0.91         0.07 -0.04
# Knuckle Curve         34442   2680          -0.37 -0.26        -0.64 -0.58
#
#                 horizontal_loc       vertical_loc       horizontal_loc_perc
# park                       AOP Coors          AOP Coors
# pitch_name
# ...

# %% [markdown]
# For left-handed pitchers, we see similar trends. Keep in mind that because our pitch movement metrics already account for handedness, now positive values in horizontal movement represent movement to the left and negative values represent movement to the right. The interpretation of location metrics stay the same.
#
# We still don't see a consistent trend in impact to pitch location vertically, though 4-seam fastballs were again located lower at Coors. But we see the same phenomenon in horizontal location: pitches are located less in the direction they're induced to move, resulting in pitches (aside from 4-seam fastballs, which as previously noted don't appear to have a typical side of the plate) located more down the middle at Coors.

# %% [markdown]
# ##### Zone Rates

# %%
zones = locations[locations.zone_full != 'error'].groupby(['park'])['zone_full'].value_counts(normalize=True).reset_index().pivot(
                                                                 index='zone_full', columns='park', values='proportion').round(3)

zone_order = {'inner heart': 1, 'heart': 2, 'shadow': 3, 'chase': 4, 'waste': 5}

zones.sort_values(by='zone_full', key=lambda x: x.map(zone_order))
# Out:
# park           AOP  Coors
# zone_full
# inner heart  0.072  0.074
# heart        0.118  0.121
# shadow       0.496  0.496
# chase        0.226  0.220
# waste        0.088  0.088

# %% [markdown]
# Another way to look at the impact on pitch location is by zone rate. Here we use [Statcast's zones](https://tangotiger.net/strikezone/zone%20chart.png), as well as an additional breakout of the "heart" zone of the innermost 6.7" x 8" space, called the "inner heart". With the reduced pitch movement forcing pitches to end up more towards middle of the strikezone (horizontally at least), we'd expect there to be an increased rate of pitches closer to the inner heart. That does seem to be the case, though to a bit less of an effect than we'd expect. Pitches in the inner heart and outer heart (shown here as just heart) increase, and pitches in the chase zone, well outside the strikezone but still competitive, decrease at Coors.

# %%
zone_by_type = pd.concat([locations[locations.zone_full != 'error'].groupby(['park', 'pitch_name'])['zone_full'].value_counts(normalize=False), 
                   locations[locations.zone_full != 'error'].groupby(['park', 'pitch_name'])['zone_full'].value_counts(normalize=True)], axis=1).reset_index().pivot(
                                                                 index='zone_full', columns=['park', 'pitch_name'], values=['count', 'proportion']).round(3)

min_pitches = 1000
zone_by_type.loc[:, zone_by_type.columns.get_level_values('pitch_name').isin(
    zone_by_type['count']['Coors'].loc[:, (zone_by_type['count']['Coors'] >= min_pitches).all()].columns)]['proportion'].sort_values(
        by='zone_full', key=lambda x: x.map(zone_order))
# Out:
# park                    AOP                                         Coors  \
# pitch_name  4-Seam Fastball Changeup Cutter Sinker Slider 4-Seam Fastball
# zone_full
# inner heart           0.084    0.046  0.072  0.079  0.066           0.084
# heart                 0.154    0.065  0.129  0.125  0.094           0.151
# shadow                0.505    0.495  0.500  0.530  0.473           0.508
# chase                 0.200    0.281  0.224  0.207  0.247           0.199
# waste                 0.057    0.114  0.074  0.059  0.120           0.058
#
# park
# pitch_name  Changeup Cutter Sinker Slider
# zone_full
# inner heart    0.054  0.071  0.080  0.072
# heart          0.075  0.123  0.133  0.100
# shadow         0.498  0.492  0.524  0.479
# chase          0.260  0.228  0.201  0.237
# waste          0.114  0.086  0.063  0.112

# %% [markdown]
# Split by pitch type, it appears as though changeups, sinkers, and sliders have increased rates in the strikezone, though this isn't the case for 4-seam fastballs and cutters.

# %%
df[df.zone_full != 'error'].groupby('zone_full')['woba_value'].mean().reset_index().round(3).sort_values(by='zone_full', key=lambda x: x.map(zone_order))
# Out:
#      zone_full  woba_value
# 2  inner heart       0.408
# 1        heart       0.361
# 3       shadow       0.299
# 0        chase       0.302
# 4        waste       0.442

# %% [markdown]
# Pitches at Coors end up closer to the middle of the strikezone, and that means batters at Coors see an uptick in desirable pitches. Pitches in the heart of the strikezone are much easier to hit, especially those in the inner heart.

# %% [markdown]
# #### Swing Outcomes

# %%
swing_list = ['hit_into_play', 'foul', 'foul_tip', 'foul_pitchout', 'swinging_pitchout', 'swinging_strike', 'swinging_strike_blocked']
miss_list = ['swinging_pitchout', 'swinging_strike', 'swinging_strike_blocked']
foul_list = ['foul', 'foul_tip', 'foul_pitchout']
swings = df[(df.description.isin(swing_list))]
swings['Result'] = swings.apply(lambda row: 'Whiff' if row['description'] in miss_list 
                                else 'Foul' if row['description'] in foul_list 
                                else 'In Play' if row['description'] == 'hit_into_play' else 'error', axis=1)

swing_order = ['Whiff', 'Foul', 'In Play']
swing_table = pd.crosstab(swings['park'], swings['Result'], normalize='index')
swing_table.columns = pd.CategoricalIndex(swing_table.columns.values, ordered=True, categories=swing_order)
swing_table = swing_table.sort_index(axis=1)
bars = swing_table['In Play'].plot(kind='bar', stacked=True, color=['green'])

# Add data labels
for container in bars.containers:
    bars.bar_label(container, fmt='{:.1%}', label_type='center', color='white', size=10.5, fontweight='bold') # Format as percentage
plt.title('Swings Resulting in Ball in Play\nCoors vs. AOP')
plt.tick_params(axis='x', labelrotation=0)
plt.xlabel('')
plt.gca().yaxis.set_major_formatter(PercentFormatter(xmax=1.0))
plt.ylim(np.min(swing_table['In Play']) * 0.9, np.max(swing_table['In Play'])*1.05)

plt.savefig("swing_outcomes.png", dpi=300)
plt.show()

# %% [markdown]
# At Coors Field, swings result in a ball in play roughly 2% more of the time. This may be due to the reduced pitch movement making it easier to make contact, though it may in part be due to the slightly increased rate of pitches in the heart of the strike zone (which also may be due to the reduced pitch movement).

# %% [markdown]
# ### The Bat

# %% [markdown]
# #### Exit Velocity and Launch Angle

# %%
# Grabbing BBEs with launch angle and exit velocity data
df_ip = df[(df.description == 'hit_into_play') & 
                   ((df.game_year >= 2020) |
                   (((df.launch_speed != 80) | (df.launch_angle != 69)) &
                   ((df.launch_speed != 82.9) | (df.launch_angle != -21)) &
                   ((df.launch_speed != 89.2) | (df.launch_angle != 39)) &
                   ((df.launch_speed != 90.3) | (df.launch_angle != -17))))]

step = 5
df_ip['ev_bucket'] = np.floor(df_ip['launch_speed'] / step) * step
df_ip['la_bucket'] = np.floor(df_ip['launch_angle'] / step) * step

# %%
plt.figure()
#sns.kdeplot(data=df_ip, x='launch_speed', hue='park', palette=['red', '#33006F'], common_norm=False)
sns.kdeplot(data=df_ip[df_ip.park == 'AOP'], x='launch_speed', color='gray', fill=True, alpha=0.3, label='AOP')
sns.kdeplot(data=df_ip[df_ip.park == 'Coors'], x='launch_speed', color='#33006F', linewidth=2, label='Coors')
plt.title('BBE Distribution by Exit Velocity\nCoors vs. AOP')
plt.xlabel('Exit Velocity (mph)')
plt.legend()
plt.show()

# %% [markdown]
# Coors doesn't appear to have any significant impact to exit velocity. With less air resistance, pitches should retain their velocity a little more by the time they get to the bat, making it easier to hit harder (though "easier" may not be the right word, as faster pitches are harder to make good contact on). According to baseball physics guru Alan Nathan, [a decrease of 20 mph in pitch speed reduces exit velocity by ~4 mph](https://www.usatoday.com/story/sports/mlb/2015/09/22/exit-velocity-harder-a-pitch-comes-in-the-harder-it-goes-out/72624244/). So if a pitch loses 3.5 mph in AOP, at Coors with 18% less air density it should only lose about 2.87 mph. That 0.63 mph increase in pitch speed at contact would only result in roughly a 0.13 mph increase in exit velocity. That may be the case, but the effect is a little too minor to notice here.

# %%
df_ip.groupby('park')['launch_speed'].mean().reset_index().round(3)
# Out:
#     park  launch_speed
# 0    AOP        88.427
# 1  Coors        88.381

# %% [markdown]
# The average exit velocity, shown here as `launch_speed`, is 0.046 mph less at Coors, even though we expected it to be more. Of course, we didn't compare the pitch speed at Coors vs. AOP, so we don't really have enough context here anyways.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
sns.kdeplot(df_ip[(df_ip.park == 'AOP') & (df_ip.pfx_z > 0)]['launch_angle'], color='gray', label='AOP', fill=True, alpha=0.3, ax=ax1)
sns.kdeplot(df_ip[(df_ip.park == 'Coors') & (df_ip.pfx_z > 0)]['launch_angle'], color='#33006F', label='Coors', linewidth=2, ax=ax1)
ax1.set_title('BBE Distribution by Launch Angle\nPitches with Upward Movement')
ax1.set_xlabel('')
ax1.set_xticks([])
ax1.set_ylabel('')
ax1.set_yticks([])

sns.kdeplot(df_ip[(df_ip.park == 'AOP') & (df_ip.pfx_z <= 0)]['launch_angle'], color='gray', label='AOP', fill=True, alpha=0.3, ax=ax2)
sns.kdeplot(df_ip[(df_ip.park == 'Coors') & (df_ip.pfx_z <= 0)]['launch_angle'], color='#33006F', label='Coors', linewidth=2, ax=ax2)
ax2.set_title('Pitches with Downward Movement')
ax2.set_xlabel('Launch Angle ($^\circ$)')
ax2.set_ylabel('')
ax2.set_yticks([])

fig.tight_layout()
plt.savefig("la_dist.png", dpi=300)
plt.show()

# %% [markdown]
# For pitches with upward induced movement, the reduced movement at Coors causes the pitches to arrive lower than they appear to be going. As a result, batters tend to get on top of the ball more at Coors, resulting in a lower distribution of launch angles from batted balls at Coors. On the other hand, pitches with downward induced movement see the opposite effect. The reduced movement at Coors causes these pitches to arrive higher than they appear to be going, resulting in batter getting under the ball and thus a higher distribution of launch angles. Given that the majority of pitches have upward induced movement, this phenomenon results in more balls in play with low launch angles (i.e. groundballs).

# %% [markdown]
# #### Hit Distance

# %% [markdown]
# Hitters may tend to get on top of the ball more often at Coors, but when they do put it in the air, the lower air density works in their favor. With less air to slow the ball down, it ends up carrying more.

# %%
aop_statcast = df_ip[df_ip.park == 'AOP'].groupby(['ev_bucket', 'la_bucket']).agg(
    dist_aop=('hit_distance_sc', 'mean'),
    count_aop=('hit_distance_sc', 'count'),
    babip_aop=('babip_value', 'mean'),
    bahb_aop=('bahb_value', 'mean'),
    iso_aop=('iso_value', 'mean'),
    woba_aop=('woba_value', 'mean'),
    xwoba_aop=('estimated_woba_using_speedangle', 'mean')
).reset_index()

col_statcast = df_ip[df_ip.park == 'Coors'].groupby(['ev_bucket', 'la_bucket']).agg(
    dist_col=('hit_distance_sc', 'mean'),
    count_col=('hit_distance_sc', 'count'),
    babip_col=('babip_value', 'mean'),
    bahb_col=('bahb_value', 'mean'),
    iso_col=('iso_value', 'mean'),
    woba_col=('woba_value', 'mean'),
    xwoba_col=('estimated_woba_using_speedangle', 'mean')
).reset_index()

statcast = pd.merge(col_statcast, aop_statcast, on=['ev_bucket', 'la_bucket'], how='inner')
statcast['distance_gap'] = statcast['dist_col'] - statcast['dist_aop']
statcast['distance_gap_perc'] = statcast['distance_gap'] / statcast['dist_aop'] * 100
statcast['babip_gap'] = statcast['babip_col'] - statcast['babip_aop']
statcast['bahb_gap'] = statcast['bahb_col'] - statcast['bahb_aop']
statcast['iso_gap'] = statcast['iso_col'] - statcast['iso_aop']
statcast['woba_gap'] = statcast['woba_col'] - statcast['woba_aop']
statcast['xwoba_gap'] = statcast['xwoba_col'] - statcast['xwoba_aop']
statcast['ev_bucket'] = statcast['ev_bucket'].astype(int)
statcast['la_bucket'] = statcast['la_bucket'].astype(int)

# %%
min_count = 10

dist_pivot = statcast[statcast.count_col >= min_count].pivot(index='la_bucket', columns='ev_bucket', values='dist_aop').astype(float)
dist_pivot_pos = dist_pivot[dist_pivot.index >= 0].dropna(axis='columns', how='all')

dist_gap_pivot = statcast[statcast.count_col >= min_count].pivot(index='la_bucket', columns='ev_bucket', values='distance_gap').astype(float)
dist_gap_pivot_pos = dist_gap_pivot[dist_gap_pivot.index >= 0].dropna(axis='columns', how='all')

dist_gap_perc_pivot = statcast[statcast.count_col >= min_count].pivot(index='la_bucket', columns='ev_bucket', values='distance_gap_perc').astype(float)
dist_gap_perc_pivot_pos = dist_gap_perc_pivot[dist_gap_perc_pivot.index >= 0].dropna(axis='columns', how='all')

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(10, 4.8))
sns.heatmap(dist_pivot_pos, cmap = 'YlGn', linewidths = 0.01, annot = False, fmt = ".0f", cbar=False, ax=ax1)
ax1.set_facecolor('lightgray')
ax1.invert_yaxis()
ax1.set_title('Avg Hit Distance (ft)\nAOP')
ax1.set_ylabel('Launch Angle ($^\circ$)')
ax1.set_xlabel('Exit Velocity (mph)')
ax1.tick_params(axis='y', labelrotation=0)

limit = abs(max(np.max(dist_gap_pivot_pos), np.min(dist_gap_pivot_pos), key=abs))
divnorm = colors.TwoSlopeNorm(vmin = -1 * limit, vcenter = 0, vmax = limit)

sns.heatmap(dist_gap_pivot_pos, cmap = 'RdYlGn', norm=divnorm, linewidths = 0.01, annot = False, fmt = ".0f", cbar=False, ax=ax2)
ax2.set_facecolor('lightgray')
ax2.invert_yaxis()
ax2.set_title('Gap in Hit Distance\nCoors vs. AOP')
ax2.set_xlabel('Exit Velocity (mph)')
ax2.set_ylabel('')
ax2.set_yticks([])

perc_limit = abs(max(np.max(dist_gap_perc_pivot_pos), np.min(dist_gap_perc_pivot_pos), key=abs))
perc_divnorm = colors.TwoSlopeNorm(vmin = -1 * perc_limit, vcenter = 0, vmax = perc_limit)

sns.heatmap(dist_gap_perc_pivot_pos, cmap = 'RdYlGn', norm=perc_divnorm, linewidths = 0.01, annot = False, fmt = ".0f", cbar=False, ax=ax3)
ax3.set_facecolor('lightgray')
ax3.invert_yaxis()
ax3.set_title('% Gap in Hit Distance\nCoors vs. AOP')
ax3.set_xlabel('Exit Velocity (mph)')
ax3.set_ylabel('')
ax3.set_yticks([])

fig.tight_layout()
plt.savefig("hit_dist.png", dpi=300)
plt.show()

# %% [markdown]
# Controlling for the batted ball's launch angle and exit velocity, balls in Colorado consistently travel farther in the air, with a larger gap for balls with further hit distances and a larger proportional gap for balls with higher launch angles (and thus more hang time).

# %%
hit_dist = df_ip[(df_ip.la_bucket >= 0)].groupby(['park', 'hit_distance_sc']).agg(
    count=('hit_distance_sc', 'count'),
    babip=('babip_value', 'mean'),
    bahb=('bahb_value', 'mean'),
    iso=('iso_value', 'mean'),
    woba=('woba_value', 'mean'),
    xwoba=('estimated_woba_using_speedangle', 'mean')
).reset_index()

# %%
window_length = 25
polyorder = 3

fig, ax1 = plt.subplots()
lns1 = sns.kdeplot(df_ip[(df_ip.park == 'Coors') & (df_ip.la_bucket >= 0)]['hit_distance_sc'], color='#33006F', label='Coors', fill=False, linewidth=2, clip=(0, 500), ax=ax1)
lns2 = sns.kdeplot(df_ip[(df_ip.park == 'AOP') & (df_ip.la_bucket >= 0)]['hit_distance_sc'], color='gray', label='AOP', fill=True, alpha=0.3, clip=(0, 500), ax=ax1)

ax1.set_title('BBE Distribution and wOBA by Hit Distance\nLA of at least 0$^\circ$')
ax1.set_ylabel('')
ax1.set_yticks([])
ax1.set_xlabel('Hit Distance (ft)')

ax2 = ax1.twinx()

lns3 = ax2.plot(hit_dist[(hit_dist.park == 'AOP')]['hit_distance_sc'], savgol_filter(hit_dist[(hit_dist.park == 'AOP')]['woba'], window_length, polyorder), color='red', label='wOBA')
ax2.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
ax2.tick_params(axis='y', colors='red')

lns = lns1.get_legend_handles_labels()[0]+lns3
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='upper left')

fig.tight_layout() # Adjust layout to prevent labels from overlapping
plt.savefig("hit_dist_woba.png", dpi=300)
plt.show()

# %% [markdown]
# The difference in hit distance distributions at Coors vs. AOP clearly show a shift to the right (more distance) for Coors. This means a higher proportion of hits in Coors end up going 350+ feet, where the largest the resulting value (wOBA) is higher.

# %%
fig, ax = plt.subplots()
ax.plot(hit_dist[(hit_dist.park == 'Coors')]['hit_distance_sc'], savgol_filter(hit_dist[(hit_dist.park == 'Coors')]['woba'], window_length*2+1, polyorder), color='#33006F', label='Coors')
ax.plot(hit_dist[(hit_dist.park == 'AOP')]['hit_distance_sc'], savgol_filter(hit_dist[(hit_dist.park == 'AOP')]['woba'], window_length, polyorder), color='red', label='AOP')
ax.set_title('wOBA by Hit Distance\nLA of at least 0$^\circ$')
ax.set_ylabel('wOBA')
ax.set_xlabel('Hit Distance (ft)')
ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
ax.legend()

fig.tight_layout() # Adjust layout to prevent labels from overlapping
plt.savefig("hit_dist_woba2.png", dpi=300)
plt.show()

# %% [markdown]
# Comparing the average wOBA by hit distance at Coors vs. AOP, there's an interesting shift here as well. All things being equal, where the ball landed (and how long it took to get there) should be the only significant factors with wOBA. The discrepancy indicates all things are not equal.

# %% [markdown]
# ### The Field

# %%
params = {'type': 'dimensions', 'year': 2015}
response = requests.get(PARK_URL, params=params)
soup = BeautifulSoup(response.content, 'html.parser')

script_tags = soup.find_all('script')
for script in script_tags:
    match = re.search('var data = (.*);', script.text)
    if match:
        break

park_dim = pd.DataFrame(json.loads(match[1])).sort_values(by='avg_fence_distance', ascending=False).reset_index()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12.8, 4.8))

pos = park_dim[park_dim.venue_name_short == 'Coors Field'].index[0]

ax1.bar(park_dim['venue_name_short'], park_dim['avg_fence_distance'], color = 'gray')
ax1.set_title('Fence Distance by MLB Stadium')
ax1.set_xlabel('MLB Stadium')
ax1.set_ylabel('Avg Fence Distance from Home (ft)')
ax1.set_ylim(np.floor(np.min(park_dim['avg_fence_distance']) * 0.95), np.ceil(np.max(park_dim['avg_fence_distance'])*1.05))
ax1.tick_params(axis='x', bottom=False, labelbottom=False)
ax1.patches[pos].set_color('#33006F')
ax1.legend(labels=[park_dim['venue_name_short'][pos]])

park_dim = park_dim.sort_values(by='fence_area', ascending=False).reset_index()
pos = park_dim[park_dim.venue_name_short == 'Coors Field'].index[0]

ax2.bar(park_dim['venue_name_short'], park_dim['fence_area'], color = 'gray')
ax2.set_title('Field Area by MLB Stadium')
ax2.set_xlabel('MLB Stadium')
ax2.set_ylabel('Playing Field Area (sq ft)')
ax2.set_ylim(np.floor(np.min(park_dim['fence_area']) * 0.95), np.ceil(np.max(park_dim['fence_area'])*1.05))
ax2.tick_params(axis='x', bottom=False, labelbottom=False)
ax2.patches[pos].set_color('#33006F')
ax2.legend(labels=[park_dim['venue_name_short'][pos]])
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

fig.tight_layout()
plt.savefig("park_dim.png", dpi=300)
plt.show()

# %% [markdown]
# We've already shown that balls carry further in Coors. This theoretically results in more home runs, so to combat that the ballpark was built with the largest outfield in Major League Baseball, with outfield fences farther away from home plate than any other MLB Stadium.
#
# Note: like with our look at park elevation, this was collected from a single year (2015). None of the new MLB stadiums used since then have had a larger average fence distance or field area.
#
# The outfield fences at Coors are about 15 feet further out than the average stadium. We believe that because of this, outfielders position themselves differently at Coors. Going back to our line charts of wOBA by hit distance, there are local minimums past 300 feet for both AOP and Coors. This is likely the distance outfielders position themselves away from home plate, making it the easiest distance for them to catch fly balls. That local minimum is around 315 feet in AOP, but at Coors it's around 330 feet. As a result, batted balls that go around 200-300 feet drop for hits at Coors more often, as the outfielders are farther away. Conversely, batted balls that go 330+ feet drop for hits less at Coors, as the outfielders are closer. There's an additional gap at even higher distances where balls that are typically home runs in AOP stay in the field at Coors due to the farther fence distance.

# %% [markdown]
# ### Impact Summary

# %% [markdown]
# ##### Coors vs. AOP

# %%
# Grabbing the final pitch of at bats
df_fin = df[(df.events.notna()) & (df.events != 'truncated_pa')]
df_fin['wOBA Gap'] = df_fin['woba_value'] - df_fin['estimated_woba_using_speedangle']

# %%
metrics = ['K%', 'BB%', 'BABIP', 'XBH%', 'HR%', 'xwOBAcon', 'wOBAcon', 'R/PA']
col_metrics = ["{:.1%}".format((df_fin[(df_fin.park == 'Coors')].events == 'strikeout').mean()),
               "{:.1%}".format((df_fin[(df_fin.park == 'Coors')].events == 'walk').mean()),
               "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.description == 'hit_into_play')].babip_value.mean()).lstrip('0'),
               "{:.1%}".format((df_fin[(df_fin.park == 'Coors')].iso_value > 0).mean()),
               "{:.1%}".format((df_fin[(df_fin.park == 'Coors')].events == 'home_run').mean()),
               "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.description == 'hit_into_play')].estimated_woba_using_speedangle.mean()).lstrip('0'),
               "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.description == 'hit_into_play')].woba_value.mean()).lstrip('0'),
               "{:.3}".format(df_fin[(df_fin.park == 'Coors')].post_bat_score.mean() - 
                              df_fin[(df_fin.park == 'Coors')].bat_score.mean()).lstrip('0')]

aop_metrics = ["{:.1%}".format((df_fin[(df_fin.park == 'AOP')].events == 'strikeout').mean()),
               "{:.1%}".format((df_fin[(df_fin.park == 'AOP')].events == 'walk').mean()),
               "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.description == 'hit_into_play')].babip_value.mean()).lstrip('0'),
               "{:.1%}".format((df_fin[(df_fin.park == 'AOP')].iso_value > 0).mean()),
               "{:.1%}".format((df_fin[(df_fin.park == 'AOP')].events == 'home_run').mean()),
               "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.description == 'hit_into_play')].estimated_woba_using_speedangle.mean()).lstrip('0'),
               "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.description == 'hit_into_play')].woba_value.mean()).lstrip('0'),
               "{:.3}".format(df_fin[(df_fin.park == 'AOP')].post_bat_score.mean() - 
                              df_fin[(df_fin.park == 'AOP')].bat_score.mean()).lstrip('0')]

off_table = pd.DataFrame()
off_table[''] = metrics
off_table['Coors'] = col_metrics
off_table['AOP'] = aop_metrics

print(off_table.to_string(index=False))
# Out:
#          Coors   AOP
#       K% 19.8% 22.3%
#      BB%  7.8%  8.0%
#    BABIP  .314  .279
#     XBH%  9.5%  7.9%
#      HR%  3.4%  3.1%
# xwOBAcon  .373  .369
#  wOBAcon  .426  .382
#     R/PA  .145  .116

# %% [markdown]
# This is the offensive performance of MLB players at Coors for AOP. We use runs per plate appearance (R/PA) instead of ERA/RA because there isn't an easy way to calculate the number of outs using this data. There's a clear gap in performance between Coors and AOP, but this may be because the Colorado Rockies are heavily weighted in this view. If Rockies batters are significantly better than the rest of MLB, or if Rockies pitchers are significantly worse, that bias could be bleeding into our read. Of course, the xwOBA at Coors vs. AOP is pretty similar, so that's likely not the case, but it's still best to try to reduce significant sampling biases.

# %% [markdown]
# ##### Coors vs. AOP - Away Team

# %%
col_metrics_away = ["{:.1%}".format((df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Top')].events == 'strikeout').mean()),
                    "{:.1%}".format((df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Top')].events == 'walk').mean()),
                    "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Top') & (df_fin.description == 'hit_into_play')].babip_value.mean()).lstrip('0'),
                    "{:.1%}".format((df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Top')].iso_value > 0).mean()),
                    "{:.1%}".format((df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Top')].events == 'home_run').mean()),
                    "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Top') & (df_fin.description == 'hit_into_play')].estimated_woba_using_speedangle.mean()).lstrip('0'),
                    "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Top') & (df_fin.description == 'hit_into_play')].woba_value.mean()).lstrip('0'),
                    "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Top')].post_bat_score.mean() - 
                                   df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Top')].bat_score.mean()).lstrip('0')]

aop_metrics_away = ["{:.1%}".format((df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top')].events == 'strikeout').mean()),
                    "{:.1%}".format((df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top')].events == 'walk').mean()),
                    "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.description == 'hit_into_play')].babip_value.mean()).lstrip('0'),
                    "{:.1%}".format((df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top')].iso_value > 0).mean()),
                    "{:.1%}".format((df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top')].events == 'home_run').mean()),
                    "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.description == 'hit_into_play')].estimated_woba_using_speedangle.mean()).lstrip('0'),
                    "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.description == 'hit_into_play')].woba_value.mean()).lstrip('0'),
                    "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top')].post_bat_score.mean() - 
                                   df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top')].bat_score.mean()).lstrip('0')]

off_table_away = pd.DataFrame()
off_table_away[''] = metrics
off_table_away['Coors'] = col_metrics_away
off_table_away['AOP'] = aop_metrics_away

print(off_table_away.to_string(index=False))
# Out:
#          Coors   AOP
#       K% 18.7% 22.7%
#      BB%  8.1%  7.7%
#    BABIP   .31  .277
#     XBH%  9.5%  7.8%
#      HR%  3.4%  3.1%
# xwOBAcon  .374  .368
#  wOBAcon  .419  .378
#     R/PA  .146  .113

# %% [markdown]
# This is the same look but only focusing on the away teams at Coors vs. AOP. Although there's still some differences in the sampling here (NL West players are more heavily represented in the Coors sample), the effects are likely minor. This'll be our main look at the summation of impact that Coors has on offensive performance.
#
# Starting first with non-BBE outcomes, batters at Coors have a reduced strikeout rate. Swings at Coors result in less misses and fouls, likely due to the reduced pitch movement and more hitter-friendly pitch locations. The strikeout rate went down more than can be attributed to just swing outcomes though. Strike zone rate doesn't appear to be the cause, as there's actually an increase of pitches in the zone at Coors if anything. We believe the likeliest reason for the additional drop in K% is due to batter swing tendencies. If batters swing more often at Coors, perhaps because they're aware of the increased value a ball in play has, that could also result in less strikeouts (assuming they aren't whiffing more, which we've shown they aren't). It could also be that because of the decreased pitch movement, batter's are able to read the pitch better and correctly determine if it's a ball or strike, allowing them to swing more at pitches in the strike zone but less at pitches out of the strike zone.
# That last hypothesis would also help explain why we're seeing an increase in walk rate at Coors too. The change from AOP to Coors is minor, but we've already shown that the strike zone rate at Coors is higher, so it seems counterintuitive. It's possible that pitchers approach the batter's count differently at Coors as well, throwing more strikes in general but less willing to throw a strike with 3 balls.
#
# When batters do put the ball in play, they have a much higher batting average at Coors, helped by the extra carry in the air and the increased field size. The large outfield makes Coors a great place to hit doubles and triples, with XBH% much higher. And while the pushed back fences help mitigate the HR%, it still ends up higher at Coors than the average park, though not the highest.
#
# xwOBAcon at Coors vs. AOP is pretty similar, though at Coors it's a tad higher. This suggests the quality of contact, park independent, is slightly better at Coors. That could be due to the changes in pitch movement and location or because batters tend to have more advantageous batter counts (which the K% and BB% would indicate). Even with that gap in xwOBAcon, though, it doesn't account for the gap in wOBAcon.
#
# With better strikeout and walk rates, as wells as better results from BBEs, the run scoring rate at Coors is about 30% higher than AOP.

# %% [markdown]
# ##### wOBA Gap

# %%
aop_statcast_type = df_ip[df_ip.park == 'AOP'].groupby(['launch_speed_angle']).agg(
    dist_aop=('hit_distance_sc', 'mean'),
    count_aop=('hit_distance_sc', 'count'),
    babip_aop=('babip_value', 'mean'),
    bahb_aop=('bahb_value', 'mean'),
    iso_aop=('iso_value', 'mean'),
    woba_aop=('woba_value', 'mean'),
    xwoba_aop=('estimated_woba_using_speedangle', 'mean')
).reset_index()

col_statcast_type = df_ip[df_ip.park == 'Coors'].groupby(['launch_speed_angle']).agg(
    dist_col=('hit_distance_sc', 'mean'),
    count_col=('hit_distance_sc', 'count'),
    babip_col=('babip_value', 'mean'),
    bahb_col=('bahb_value', 'mean'),
    iso_col=('iso_value', 'mean'),
    woba_col=('woba_value', 'mean'),
    xwoba_col=('estimated_woba_using_speedangle', 'mean')
).reset_index()

statcast_type = pd.merge(col_statcast_type, aop_statcast_type, on=['launch_speed_angle'], how='inner')
statcast_type['distance_gap'] = statcast_type['dist_col'] - statcast_type['dist_aop']
statcast_type['distance_gap_perc'] = statcast_type['distance_gap'] / statcast_type['dist_aop'] * 100
statcast_type['babip_gap'] = statcast_type['babip_col'] - statcast_type['babip_aop']
statcast_type['bahb_gap'] = statcast_type['bahb_col'] - statcast_type['bahb_aop']
statcast_type['iso_gap'] = statcast_type['iso_col'] - statcast_type['iso_aop']
statcast_type['woba_gap'] = statcast_type['woba_col'] - statcast_type['woba_aop']
statcast_type['xwoba_gap'] = statcast_type['xwoba_col'] - statcast_type['xwoba_aop']

# %%
launch_speed_angle = ['n/a', 'Weak', 'Topped', 'Under', 'Flare/Burner', 'Solid\nContact', 'Barrel']

fig, ax = plt.subplots()
rects1 = ax.bar(statcast_type['launch_speed_angle'] - 0.15, statcast_type['xwoba_gap'], 0.3, label='xwOBA Gap')
rects2 = ax.bar(statcast_type['launch_speed_angle'] + 0.15, statcast_type['woba_gap'], 0.3, label='wOBA Gap')
ax.set_ylabel('')
ax.set_title('Gap in xwOBA/wOBA Between Coors and AOP\nby BBE Type')
ax.set_xticklabels(launch_speed_angle)
ax.legend(loc='upper left')

plt.show()

# %% [markdown]
# Going further with our analysis of performance, one way to account for the quality of contact is by splitting performance by BBE type. Using LA and EV, Statcast [categorizes BBEs](https://batsandstats.com/2019/05/14/statcast-school-barrels/). There's weak contact (i.e. dribblers), topped balls (groundballs), hit under (flyballs), and flares/burners (think bloopers and scorching groundballs). The last two are solid contact and barrels, which represent BBEs with the most desirable combinations of LA and EV, with barrels a step above solid contact in that regard.
#
# The xwOBA gap between Coors and AOP is next to nothing, though unders and barrels both have a small gap that may be worth looking into further another time. Despite the lack in xwOBA gap, there is a gap in wOBA, especially for solid contact and barrels. Unders and flares/burners both had solid gap, significant but not to the extent of solid contact and barrels.
#
# Interestingly, topped balls also had a gap between Coors and AOP. The primary difference of Coors we've shown so far has been regarding the hit distance and outfield size, neither of which would seem to affect groundballs. This gap suggests there's an additional effect of Coors that we haven't covered. It's possible that groundballs that break through the infield are more likely to turn into extra-base hits since outfielders are farther away. It's also possible that groundballs move differently at Coors, making it harder for infielders to make a play on them.

# %%
team_gaps = df_fin.groupby('home_team')['wOBA Gap'].mean().sort_values(ascending=False).reset_index()

pos = team_gaps[team_gaps.home_team == 'COL'].index[0]

fig, ax = plt.subplots()
ax.bar(team_gaps['home_team'], team_gaps['wOBA Gap'], color = 'gray')
ax.set_title('Gap in Expected vs. Actual wOBA by MLB Stadium')
ax.set_xlabel('Home Team')
ax.set_ylabel('wOBA Gap')
ax.tick_params(axis='x', bottom=False, labelbottom=False)
ax.patches[pos].set_color('#33006F')
ax.legend(labels=[team_gaps['home_team'][pos]])

plt.savefig("woba_by_park.png", dpi=300)
plt.show()

# %% [markdown]
# We've pretty much confirmed that Coors is a hitter friendly park compared to the average park. Now we want to see if Coors Field is merely a hitter friendly park or if it's something more. To do this, we looked at offensive performance at each stadium (technically merging all home stadiums for each team together, though the difference is negligible). We're showing the gap in xwOBA and wOBA to remove the influence of contact quality and hone in on the effects of the field itself.
#
# Note that this gap is different than what we saw in the previous chart. That was gap between Coors and AOP (`wOBA at Coors - wOBA at AOP`) while this is gap between wOBA and xwOBA (`wOBA - xwOBA`).
#
# MLB players tend to outperform their expected wOBA, but they do so most at Coors Field, far more than any other park. And this doesn't even account for the decreased strikeout rate and increased walk rate, since those are baked into both xwOBA and wOBA and thus removed from this look.

# %% [markdown]
# ##### Colorado Rockies - Home vs. Away

# %%
home_metrics = ["{:.1%}".format((df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Bot')].events == 'strikeout').mean()),
                    "{:.1%}".format((df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Bot')].events == 'walk').mean()),
                    "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Bot') & (df_fin.description == 'hit_into_play')].babip_value.mean()).lstrip('0'),
                    "{:.1%}".format((df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Bot')].iso_value > 0).mean()),
                    "{:.1%}".format((df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Bot')].events == 'home_run').mean()),
                    "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Bot') & (df_fin.description == 'hit_into_play')].estimated_woba_using_speedangle.mean()).lstrip('0'),
                    "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Bot') & (df_fin.description == 'hit_into_play')].woba_value.mean()).lstrip('0'),
                    "{:.3}".format(df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Bot')].post_bat_score.mean() - 
                                   df_fin[(df_fin.park == 'Coors') & (df_fin.inning_topbot == 'Bot')].bat_score.mean()).lstrip('0')]

away_metrics = ["{:.1%}".format((df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.away_team == 'COL')].events == 'strikeout').mean()),
                    "{:.1%}".format((df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.away_team == 'COL')].events == 'walk').mean()),
                    "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.away_team == 'COL') & (df_fin.description == 'hit_into_play')].babip_value.mean()).lstrip('0'),
                    "{:.1%}".format((df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.away_team == 'COL')].iso_value > 0).mean()),
                    "{:.1%}".format((df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.away_team == 'COL')].events == 'home_run').mean()),
                    "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.away_team == 'COL') & (df_fin.description == 'hit_into_play')].estimated_woba_using_speedangle.mean()).lstrip('0'),
                    "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.away_team == 'COL') & (df_fin.description == 'hit_into_play')].woba_value.mean()).lstrip('0'),
                    "{:.3}".format(df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.away_team == 'COL')].post_bat_score.mean() - 
                                   df_fin[(df_fin.park == 'AOP') & (df_fin.inning_topbot == 'Top') & (df_fin.away_team == 'COL')].bat_score.mean()).lstrip('0')]

off_table_col = pd.DataFrame()
off_table_col[''] = metrics
off_table_col['Home'] = home_metrics
off_table_col['Away'] = away_metrics

print(off_table_col.to_string(index=False))
# Out:
#           Home  Away
#       K% 21.1% 25.8%
#      BB%  7.5%  6.8%
#    BABIP  .318  .273
#     XBH%  9.6%  7.1%
#      HR%  3.4%  2.6%
# xwOBAcon  .372  .355
#  wOBAcon  .432  .363
#     R/PA  .144  .097

# %% [markdown]
# This is an alternative way to account for sampling biases: focus only on Rockies performance at home (Coors) vs. on the road (AOP). This shows all the same trends, directionally, as the previous view, though the magnitude of the gaps have changed. This suggests the existence of an additional effect of Coors, one known as the Coors Hangover Effect, which we'll cover in Part 2 and leads us to our next steps.

# %% [markdown]
# ### Next Steps
#
# As suggested above, Part 2 will cover the additional effect Coors Field has on batters away from the park. Some other topics still to analyze regarding Coors:
#
# - Groundballs, including fielding impact
# - Changes in effect over time
# - Batter/pitcher profiles that see more/less impact to performance
#
# This first part may be informative to those that don't follow baseball, but it doesn't really reveal anything that hasn't been covered before. Still, it's the foundation for a lot of further, more relevant analysis that can be used to gather actionable insights for MLB teams like the Colorado Rockies. Although this project is just an exercise, we still aim to produce results that can drive decision-making.
